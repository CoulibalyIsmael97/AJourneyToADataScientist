# %% [raw]
# Le temps de retard total d'un vol est la somme des retards liés à la météo(WeatherDelay), à la sécurité au sein de l'aéroport(SecurityDelay), à la compagnie (CarrierDelay) et au système de sécurité national (NASDelay).
#
# - La variable WeatherDelay est prédite en uilisant un algorithme de regression linéaire à partir des données météorolgiques
#
# - La variable SecurityDelay est calculée en faisant une moyenne par mois et par aéroport.
#
# - La variable CarrierDelay est calculée en faisant une moyenne par mois et par compagnie.
#
# - La variable NASDelay est calculée en faisant une moyenne par mois et par heure.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error, median_absolute_error

# %%
df_SD = pd.read_csv('SecurityDelay.csv')
df_CD = pd.read_csv('CarrierDelay_Proba.csv')
df_NASD = pd.read_csv('NASDelay_Proba.csv')

# %%
'''
Cette fonction prédit le temps de retard total en minutes et prend en paramètres:
- compagnie: le code de la compagnie aérienne uilisée pour le voyage
- mois : le mois pendant lequel le voyage a lieu. Ici le mois est utilisé par soucis simplicité de programmation sinon
         on devrait plutôt renseigner la date(jour, mois, année)
- temperature : la valeur de la temperature (en Fahrenheit)
- relativeHumidity : la proportion d'humidité (en Pourcentage)
- windSpeed: la vitesse du vent (en miles par heure)
- heure : l'heure de départ (en heure)
- aeroport: le code de l'aeroport de départ

Cette fonction fait une requête dans les differents fichiers csv pour recupérer les valeurs de SecurityDelay, 
CarrierDelay,NASDelay
'''


def prediction(compagnie,mois,temperature,relativeHumidity,windSpeed,visibility,heure,aeroport):
    WeatherDelay=0.0263*temperature+ 0.2482*relativeHumidity+1.2027*windSpeed-0.4090*visibility
    SecurityDelay = df_SD[(df_SD['Month'] == mois) & (df_SD['Origin'] == aeroport)]['SecurityDelayMean'].values[0]
    CarrierDelay = df_CD[(df_CD['Month'] == mois) & (df_CD['UniqueCarrier'] == compagnie)]['proba_CarrierDelay'].values[0]
    NASDelay = df_NASD[(df_NASD['Hour'] == heure)]['proba_NASDelay'].values[0]
    tempsDeRetardTotal=WeatherDelay+SecurityDelay+CarrierDelay+NASDelay
    
    return tempsDeRetardTotal,SecurityDelay,CarrierDelay

# %% [markdown]
# # Exemples de prédicion

# %%
prediction('AA','April',71,49.66,18.9,10,19,'IND')
# Out:
# (36.716798060062196, 3.171007927519818, 0.03963149564970343)

# %%
prediction('WN','January',16.6,70.99,8.1,10,17,'IND')
# Out:
# (39.09146031899965, 14.421997755331088, 0.03430967222771876)

# %% [markdown]
# # Comparaison temps de retard total réél et temps de retard total prédit

# %%
# Convertion des numeros des mois en chaine de caractères
def numToMonth(x):
    if x==1:
        return "January"
    if x==2:
        return "February"
    if x==3:
        return "March"
    if x==4:
        return "April"
    if x==5:
        return "May"
    if x==6:
        return "June"
    if x==7:
        return "July"
    if x==8:
        return "August"
    if x==9:
        return "September"
    if x==10:
        return "October"
    if x==11:
        return "November"
    if x==12:
        return "December"

# %%
df=pd.read_csv('Jointed_ficher_v1.csv')

# %%
df['Month']= df['Month'].apply(lambda x : numToMonth(x) )

# %%
df_RP=df.loc[:,['Start_Date','Month','Hour','UniqueCarrier','Origin','Temperature','Relative Humidity','Wind Speed','Visibility','ArrDelay']]
df_RP.head()
# Out:
#             Start_Date    Month  Hour UniqueCarrier Origin  Temperature  \
# 0  2008-01-03 17:00:00  January    17            WN    IND         16.6
# 1  2008-01-03 17:00:00  January    17            EV    IND         16.6
# 2  2008-01-03 17:00:00  January    17            9E    IND         16.6
# 3  2008-01-03 18:00:00  January    18            WN    IND         19.1
# 4  2008-01-03 18:00:00  January    18            NW    IND         19.1
#
#    Relative Humidity  Wind Speed  Visibility  ArrDelay
# 0              70.99         8.1        10.0      34.0
# 1              70.99         8.1        10.0      49.0
# 2              70.99         8.1        10.0     201.0
# 3              67.40         7.7        10.0      57.0
# 4              67.40         7.7        10.0      24.0

# %%
df_RP['PredictWeatherDelay']=0.0214*df_RP['Temperature']+ 0.2499*df_RP['Relative Humidity']+1.1926*df_RP['Wind Speed']-0.3787*df_RP['Visibility']

# %%
df_RP=pd.merge(df_RP, df_SD,on=['Month','Origin'])

# %%
df_RP=pd.merge(df_RP, df_CD,on=['Month','UniqueCarrier'])

# %%
df_RP=pd.merge(df_RP, df_NASD,on=['Hour'])

# %%
df_RP['PredictDelay']=df_RP['PredictWeatherDelay']+df_RP['SecurityDelayMean']+df_RP['proba_CarrierDelay']+df_RP['proba_NASDelay']
df_RP.head()
# Out:
#             Start_Date    Month  Hour UniqueCarrier Origin  Temperature  \
# 0  2008-01-03 17:00:00  January    17            WN    IND         16.6
# 1  2008-01-05 17:00:00  January    17            WN    IND         41.1
# 2  2008-01-07 17:00:00  January    17            WN    IND         65.0
# 3  2008-01-13 17:00:00  January    17            WN    IND         32.1
# 4  2008-01-23 17:00:00  January    17            WN    IND         23.1
#
#    Relative Humidity  Wind Speed  Visibility  ArrDelay  ...  Unnamed: 0_x  \
# 0              70.99         8.1        10.0      34.0  ...            93
# 1              80.29        10.2        10.0      51.0  ...            93
# 2              71.63        16.1        10.0     382.0  ...            93
# 3              90.95        13.9         0.7      23.0  ...            93
# 4              56.99         8.4        10.0      37.0  ...            93
#
#    CarrierDelayMean  proba_company_carrier  proba_mois_carrier  \
# 0         10.618113                0.07206            0.044841
# 1         10.618113                0.07206            0.044841
# 2         10.618113                0.07206            0.044841
# 3         10.618113                0.07206            0.044841
# 4         10.618113                0.07206            0.044841
#
#    proba_CarrierDelay  Unnamed: 0_y  NASDelayMean  proba_hour_Nas  \
# 0             0.03431            16     18.891582        0.049069
# 1             0.03431            16     18.891582        0.049069
# 2             0.03431            16     18.891582        0.049069
# 3             0.03431            16     18.891582        0.049069
# 4             0.03431            16     18.891582        0.049069
#
#    proba_NASDelay  PredictDelay
# 0        0.926985     39.351993
# 1        0.926985     44.704823
# 2        0.926985     50.088489
# 3        0.926985     55.110687
# 4        0.926985     36.350273
#
# [5 rows x 22 columns]

# %%
def reduceTime(x):
    if x<60:
        return x-15
    if (x>=60 and x<180):
        return x-30
    if x>=180:
        return x-60

# %%
def addTime(x):
    if x<60:
        return x+15
    if (x>=60 and x<180):
        return x+30
    if x>=180:
        return x+60

# %%
df_RP['PredictDelayLess']=df_RP['PredictDelay'].apply(lambda x : reduceTime(x))
df_RP['PredictDelayMore']=df_RP['PredictDelay'].apply(lambda x : addTime(x))

# %%
df_RP
# Out:
#                   Start_Date      Month  Hour UniqueCarrier Origin  \
# 10          43.072442         28.072442         58.072442
# 11          43.072442         28.072442         58.072442
# 12           8.818202         -6.181798         23.818202
# 13           8.818202         -6.181798         23.818202
# 14           8.818202         -6.181798         23.818202
# 15           8.818202         -6.181798         23.818202
# 16           8.818202         -6.181798         23.818202
# 17           8.818202         -6.181798         23.818202
# 18           8.818202         -6.181798         23.818202
# 19           8.818202         -6.181798         23.818202
# 20           8.818202         -6.181798         23.818202
# 21           8.818202         -6.181798         23.818202
# 22           8.818202         -6.181798         23.818202
# 23           8.818202         -6.181798         23.818202
# 24           8.818202         -6.181798         23.818202
# 25           8.818202         -6.181798         23.818202
# 26           8.818202         -6.181798         23.818202
# 27           8.818202         -6.181798         23.818202
# 28           8.818202         -6.181798         23.818202
# 29          13.068078         -1.931922         28.068078
# ...               ...               ...               ...
# 1110108     22.693944          7.693944         37.693944
# 1110109      5.473749         -9.526251         20.473749
# 1110110     13.935203         -1.064797         28.935203
# 1110111     20.602423          5.602423         35.602423
# 1110112     17.093453          2.093453         32.093453
# 1110113     19.724861          4.724861         34.724861
# 1110114     22.141745          7.141745         37.141745
# 1110115     26.395414         11.395414         41.395414
# 1110116     30.845157         15.845157         45.845157
# 1110117     10.395075         -4.604925         25.395075
# 1110118     17.740982          2.740982         32.740982
# 1110119     23.551556          8.551556         38.551556
# 1110120     16.536433          1.536433         31.536433
# 1110121     28.924164         13.924164         43.924164
# 1110122     35.380664         20.380664         50.380664
# 1110123     19.947076          4.947076         34.947076
# 1110124     20.886185          5.886185         35.886185
# 1110125     12.064848         -2.935152         27.064848
# 1110126      5.865759         -9.134241         20.865759
# 1110127      6.008242         -8.991758         21.008242
# 1110128     17.095608          2.095608         32.095608
# 1110129     14.708164         -0.291836         29.708164
# 1110130     12.755600         -2.244400         27.755600
# 1110131     13.481511         -1.518489         28.481511
# 1110132     16.295051          1.295051         31.295051
# 1110133     33.418254         18.418254         48.418254
# 1110134     21.613910          6.613910         36.613910
# 1110135     37.651755         22.651755         52.651755
# 1110136     20.477977          5.477977         35.477977
# 1110137     20.380781          5.380781         35.380781
#
# [1110138 rows x 24 columns]

# %% [markdown]
# # Calcul du score R2 (qualité de prédiction d'une regression linéaire)

# %%
moyenne=df_RP['ArrDelay'].mean()
df_RP['SSEi']=(df_RP['PredictDelay']-moyenne)**2

df_RP['SSELessi']=(df_RP['PredictDelayLess']-moyenne)**2

df_RP['SSEMorei']=(df_RP['PredictDelayMore']-moyenne)**2

df_RP['SSTi']=(df_RP['ArrDelay']-moyenne)**2

df_RP.head()
# Out:
#             Start_Date    Month  Hour UniqueCarrier Origin  Temperature  \
# 0  2008-01-03 17:00:00  January    17            WN    IND         16.6
# 1  2008-01-05 17:00:00  January    17            WN    IND         41.1
# 2  2008-01-07 17:00:00  January    17            WN    IND         65.0
# 3  2008-01-13 17:00:00  January    17            WN    IND         32.1
# 4  2008-01-23 17:00:00  January    17            WN    IND         23.1
#
#    Relative Humidity  Wind Speed  Visibility  ArrDelay  ...  NASDelayMean  \
# 0              70.99         8.1        10.0      34.0  ...     18.891582
# 1              80.29        10.2        10.0      51.0  ...     18.891582
# 2              71.63        16.1        10.0     382.0  ...     18.891582
# 3              90.95        13.9         0.7      23.0  ...     18.891582
# 4              56.99         8.4        10.0      37.0  ...     18.891582
#
#    proba_hour_Nas  proba_NASDelay  PredictDelay  PredictDelayLess  \
# 0        0.049069        0.926985     39.351993         24.351993
# 1        0.049069        0.926985     44.704823         29.704823
# 2        0.049069        0.926985     50.088489         35.088489
# 3        0.049069        0.926985     55.110687         40.110687
# 4        0.049069        0.926985     36.350273         21.350273
#
#    PredictDelayMore        SSEi     SSELessi    SSEMorei           SSTi
# 0         54.351993  267.724503   983.593174    1.855831     471.510059
# 1         59.704823  121.208189   676.491960   15.924417      22.224458
# 2         65.088489   31.649547   425.423339   87.875756  106462.369530
# 3         70.110687    0.364327   243.472178  207.256475    1070.224271
# 4         51.350273  374.964846  1180.885118   19.044575     350.224365
#
# [5 rows x 28 columns]

# %%
r2_scoreMe=df_RP['SSEi'].sum()/df_RP['SSTi'].sum()
r2_scoreMe
# Out:
# 0.27416805666560773

# %%
r2_scoreLess=df_RP['SSELessi'].sum()/df_RP['SSTi'].sum()
r2_scoreLess
# Out:
# 0.6242814377374459

# %%
r2_scoreMore=df_RP['SSEMorei'].sum()/df_RP['SSTi'].sum()
r2_scoreMore
# Out:
# 0.07852708333488835

# %%
type(df_RP['PredictDelay'].values)
# Out:
# numpy.ndarray

# %%
from sklearn.metrics import mean_squared_error, r2_score
r2_score(df_RP['ArrDelay'].values,df_RP['PredictDelay'].values)
# Out:
# -0.24163806628169016

# %%
r2_score(df_RP['ArrDelay'].values,df_RP['PredictDelayMore'].values)
# Out:
# -0.04548642321932417

# %%
r2_score(df_RP['ArrDelay'].values,df_RP['PredictDelayLess'].values)
# Out:
# -0.5922621170851758

# %%
print('Mean Absolute Error:', mean_absolute_error(df_RP['ArrDelay'].values,df_RP['PredictDelayLess'].values))
print('Mean Squared Error:', mean_squared_error(df_RP['ArrDelay'].values,df_RP['PredictDelayLess'].values))
print('Root Mean Squared Error:', np.sqrt(mean_squared_error(df_RP['ArrDelay'].values,df_RP['PredictDelayLess'].values)))
# Out:
# Mean Absolute Error: 42.81446824509657
# Mean Squared Error: 4689.100918268808
# Root Mean Squared Error: 68.47701014405351

# %%
print('Mean Absolute Error:', mean_absolute_error(df_RP['ArrDelay'].values,df_RP['PredictDelay'].values))
print('Mean Squared Error:', mean_squared_error(df_RP['ArrDelay'].values,df_RP['PredictDelay'].values))
print('Root Mean Squared Error:', np.sqrt(mean_squared_error(df_RP['ArrDelay'].values,df_RP['PredictDelay'].values)))
# Out:
# Mean Absolute Error: 33.904753752284385
# Mean Squared Error: 3656.5375350492814
# Root Mean Squared Error: 60.46931068773053

# %%
print('Mean Absolute Error:', mean_absolute_error(df_RP['ArrDelay'].values,df_RP['PredictDelayMore'].values))
print('Mean Squared Error:', mean_squared_error(df_RP['ArrDelay'].values,df_RP['PredictDelayMore'].values))
print('Root Mean Squared Error:', np.sqrt(mean_squared_error(df_RP['ArrDelay'].values,df_RP['PredictDelayMore'].values)))
# Out:
# Mean Absolute Error: 32.89207421636359
# Mean Squared Error: 3078.884622419901
# Root Mean Squared Error: 55.48769793765012
